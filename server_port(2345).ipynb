# %%
import cv2
import numpy as np
import socket
import time
import threading

# %%
def recv_d():
    r = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
    r.bind(("127.0.0.1",2345))
    r.listen()
    sess,add = r.accept()
    print(sess.recv(1024))
    print("Live streaming started ")
    while True:
        data_r = sess.recv(100000000)
        image_r = np.frombuffer(data_r , np.uint8)
        if len(image_r) == 600*500*3:
            cv2.imshow("live streaming",image_r.reshape(500,600,3))
            if cv2.waitKey(10) == 13:
                cv2.destroyAllWindows()
                break
        else:
            print("frame lost")
            
def send_d():
    time.sleep(3)
    s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
    s.connect(("127.0.0.1",1234))
    s.send(b"connection established , port_no = 1234")
    cap = cv2.VideoCapture(1)
    print("Live streaming started ")
    while True:
        capture,photo= cap.read()
        if capture:
            photo = cv2.resize(photo,(600,500))
            s.send(np.ndarray.tobytes(photo))
        else:
            print("No image to send")
            

recv_t = threading.Thread(target = recv_d).start()
send_t = threading.Thread(target = send_d).start()
# Out:
# b'connection established , port_no = 2345'
# Live streaming started
# Live streaming started
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "C:\Users\user\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-07c83dc620ac>", line 30, in send_d
#     s.send(np.ndarray.tobytes(photo))
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
# frame lost
